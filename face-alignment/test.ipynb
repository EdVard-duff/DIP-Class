# %%
import face_alignment
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._2D, flip_input=False,device='cpu',face_detector='sfd')

input = io.imread(r'..\I2G\faces.jpg')
preds = fa.get_landmarks(input)
preds = np.array(preds)
preds.shape
preds
# Out:
# (31, 68, 2)
# array([[[3053., 1678.],
#         [3056., 1696.],
#         [3060., 1713.],
#         ...,
#         [3135., 1741.],
#         [3128., 1743.],
#         [3119., 1741.]],
#
#        [[1123., 1194.],
#         [1125., 1209.],
#         [1126., 1222.],
#         ...,
#         [1181., 1243.],
#         [1175., 1245.],
#         [1168., 1243.]],
#
#        [[1561., 1718.],
#         [1561., 1733.],
#         [1565., 1748.],
#         ...,
#         [1624., 1774.],
#         [1619., 1776.],
#         [1613., 1776.]],
#
#        ...,
#
#        [[1894., 1177.],
#         [1897., 1189.],
#         [1902., 1200.],
#         ...,
#         [1952., 1209.],
#         [1945., 1211.],
#         [1941., 1211.]],
#
#        [[3011., 1215.],
#         [3019., 1202.],
#         [3023., 1199.],
#         ...,
#         [2986., 1173.],
#         [2990., 1168.],
#         [2988., 1179.]],
#
#        [[1849., 2363.],
#         [1852., 2380.],
#         [1863., 2400.],
#         ...,
#         [1920., 2400.],
#         [1914., 2400.],
#         [1909., 2402.]]], dtype=float32)

# %%
plt.imshow(input)
for detection in preds:
    plt.scatter(detection[:,0],detection[:,1])
